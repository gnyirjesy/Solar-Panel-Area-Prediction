# %% [markdown]
# # Setup

# %%
#Import Python libraries
from sklearn.model_selection import train_test_split,\
StratifiedKFold,\
RandomizedSearchCV,\
GridSearchCV
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

#actually used in this script
#Import Python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PowerTransformer, MinMaxScaler, StandardScaler
import tensorflow as tf
import pickle
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import scipy
from tensorflow import keras
from IPython.core.interactiveshell import InteractiveShell

#Set options for notebook display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
InteractiveShell.ast_node_interactivity = 'all'

#Set seed for reproducability
seed = 111

# %%
#Define functions
def find_na_columns(df: pd.DataFrame):
    """
    Function to list columns that contain n/a's
    Input: df: pd.DataFrame
    Output: List of column names
    """
    na_cols = []
    for col in df:
        if df[col].isna().any():
            na_cols.append(col)
    return(na_cols)

#Imputation
def impute_values(train_df: pd.DataFrame, test_df: pd.DataFrame, column: str, group_column: str,  impute_value='mean'):
    """
    Function to impute missing values for numeric variables. Group column used to make imputations by mean more accurate.
    Input: train_df: pd.DataFrame, train data
            test_df: pd.DataFrame, test data
            column: str, column to impute
            group_column: str, column to group by for imputing
            impute_value: str ('mean', 'median')
    Output: dataframe with column with all missing values imputed to impute value
    """
    if impute_value == 'mean':
        subset = train_df[[column,group_column]].groupby(group_column).mean()
    elif impute_value == 'median':
        subset = train_df[[column,group_column]].groupby(group_column).median()
    elif impute_value == 'zero':
        df[column] = np.where(df[column].isna(), 0, df[column])
        return(df)
    else:
        raise Exception('That impute value is invalid. Options include mean or median.')
    subset = subset.reset_index()
    subset = subset.rename(columns={column: 'impute_val'})
    train_df = train_df.merge(subset, how='left', on=group_column)
    train_df[column] = np.where(train_df[column].isna(), train_df['impute_val'], train_df[column])
    train_df = train_df.drop('impute_val', axis=1)
    
    test_df = test_df.merge(subset, how='left', on=group_column)
    test_df[column] = np.where(test_df[column].isna(), test_df['impute_val'], test_df[column])
    test_df = test_df.drop('impute_val', axis=1)
    return(train_df, test_df)

def transformation_comparison(df: pd.DataFrame, column: str):
    """
    Function to create plots to compare log, min_max_scaler, and standard_scaler transformation of a 
    numeric column.
    
    Inputs: df: pd.DataFrame
            column: str, the name of a numeric column in the dataframe
            
    Outputs:
            None, print a plot showing a histogram of the data with different transformations
            
    Source: https://towardsdatascience.com/how-to-differentiate-between-scaling-normalization-and-log-transformations-69873d365a94
    """
    try:
        #If the column is strictly positive, use the box-cox method of power transformation
        if df[column].min() > 0:
            pt = PowerTransformer('box-cox')
        else:
            pt = PowerTransformer('yeo-johnson')
        fig, axes = plt.subplots(1,4, figsize=(15,3))
        _ = df.hist(column, ax = axes[0])
        #df['log_col'] = df[col].apply(lambda x: np.log(x+1))
        df[["log_col"]] = pd.DataFrame(pt.fit_transform(df[[column]]), columns=[column])
        _ = df.hist('log_col', ax = axes[1])
        mms = MinMaxScaler()
        df[['min_max_col']] = pd.DataFrame(mms.fit_transform(df[[column]]), columns=[column])
        _ = df.hist('min_max_col', ax = axes[2])
        ss = StandardScaler()
        df[['standar_scaler_col']] = pd.DataFrame(ss.fit_transform(df[[column]]), columns=[column])
        _ = df.hist('standar_scaler_col', ax = axes[3])
        title_text = 'Comparing Transformations of '+column
        _ = plt.title(title_text)
        _ = plt.show()
    except:
        raise Exception(col, ' did not plot')

def remove_correlation(df: pd.DataFrame, target: str, threshold = .8):
    """
    Function to remove correlated columns. Find the columns that have a correlation above the absolute value of the
    threshold. Remove the column that is least correlated with the target variable until there are no more highly 
    correlated columns.
    Inputs:
        df: pd.DataFrame
        target: str, column name of target variable
        threshold: float, the correlation coefficient threshold to consider significant
    Outputs:
        pd.Dataframe with least correlated column removed
        list of dropped columns
    """
    corr_cols = ['placeholder']
    dropped_cols = []
    while len(corr_cols) > 0:
        correlation_matrix = df.corr()
        corr_df = pd.DataFrame(correlation_matrix.unstack(),columns = ['correlation_coef'])
        corr_df = corr_df.reset_index()
        corr_df_significant = corr_df[((corr_df['correlation_coef'] > .8)|(corr_df['correlation_coef'] < -.8))&(corr_df['level_0'] != corr_df['level_1'])]
        corr_cols = corr_df_significant['level_0'].unique()
        if target in corr_cols:
            corr_cols.remove(target)
        if len(corr_cols) == 0:
            return(df, dropped_cols)
        subset = corr_df[(corr_df['level_0'] ==target)&(corr_df['level_1'].isin(corr_cols))]
        subset['correlation_coef'] = abs(subset['correlation_coef'])
        drop_col = subset['level_1'].loc[subset['correlation_coef'].idxmin()]
        dropped_cols.append(drop_col)
        df = df.drop(drop_col, axis=1)

def plot_feature_importance(importance, names):
    '''
    this code is from here: 
    https://www.analyseup.com/learn-python-for-data-science/python-random-forest-feature-importance-plot.html
    '''
    #Create arrays from feature importance and feature names
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    #Create a DataFrame using a Dictionary
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)

    #Sort the DataFrame in order decreasing feature importance
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_df = fi_df[fi_df['feature_importance'] > .01]
    #Define size of bar plot
    plt.figure(figsize=(10,8))
    #Plot Searborn bar chart
    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])
    #Add chart labels
    plt.title('FEATURE IMPORTANCE')
    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')
    return(fi_df)

def regression_scatter(x: pd.Series, y: pd.Series, xlabel=None, ylabel=None, title=None, save_loc=None):
    """
    Function to create a scatter plot and calculate the r-squared term between x and y series
    
    INPUTS: x: pd.Series of x values
            y: pd.Series of y values
            xlabel: str, xlabel for plot
            ylabel: str, ylabel for plot
            title: str, title for plot
            save_loc: str, directory to save plot
    OUTPUT:
            graph image
    """
    slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
    ax = sns.regplot(x = x, y = y,
   line_kws = {
      'label': "R-squared: {}".format(round(r_value*r_value,3))
   })
    # plot legend
    _ = ax.legend()
    _ = plt.xlabel(xlabel)
    _ = plt.ylabel(ylabel)
    _ = plt.title(title)
    _ = plt.show()
    
    if save_loc:
        plt.savefig(save_loc+'.png')

# %% [markdown]
# # Data Cleaning and Preparation
# * Correct data types
# * Imputation (median by county)
# * Remove correlated features

# %%
#Read in data
df = pd.read_pickle('/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/data/deepsolar_tract_clean.pkl')
#Print an overview of the data set
df.head()
# Out:
#    tile_count  solar_system_count  total_panel_area         fips  \
# 0         0.0                 0.0          0.000000  27145011200
# 1        25.0                21.0       1133.436461  27145011301
# 2         3.0                 3.0         64.505776  27145011302
# 3         0.0                 0.0          0.000000  27145011304
# 4         5.0                 5.0        164.583303  27145011400
#
#    average_household_income          county  education_bachelor  \
# 0              70352.789869  Stearns County                 569
# 1              61727.085202  Stearns County                 674
# 2              71496.886583  Stearns County                 854
# 3              86840.152755  Stearns County                 640
# 4              89135.315597  Stearns County                 654
#
#    education_college  education_doctoral  education_high_school_graduate  \
# 0               1690                  13                            1757
# 1               1434                 108                             767
# 2               1459                  31                            1541
# 3               1116                  68                            1095
# 4               1314                  15                             982
#
#    education_less_than_high_school  education_master  education_population  \
# 0                              336               157                  4548
# 1                              222               285                  3533
# 2                              289               276                  4480
# 3                              231               270                  3456
# 4                              163               170                  3348
#
#    education_professional_school  employed  gini_index  \
# 0                             26      3569      0.3490
# 1                             43      4795      0.4074
# 2                             30      3550      0.3926
# 3                             36      3483      0.3949
# 4                             50      2887      0.4463
#
#    heating_fuel_coal_coke  heating_fuel_electricity  \
# 0                     200                       448
# 1                      20                       379
# 2                      69                       440
# 3                     188                       442
# 4                      96                       497
#
#    heating_fuel_fuel_oil_kerosene  heating_fuel_gas  \
# 0                              98              1720
# 1                              17              1799
# 2                              45              2098
# 3                              61              1113
# 4                              47              1202
#
#    heating_fuel_housing_unit_count  heating_fuel_none  heating_fuel_other  \
# 0                             2527                 10                  51
# 1                             2230                  0                  15
# 2                             2698                 29                  17
# 3                             1833                 13                  16
# 4                             1917                 31                  44
#
#    heating_fuel_solar  land_area  per_capita_income  population  \
# 0                   0  147.73120            26999.0        6577
# 1                   0   16.61679            20951.0        8020
# 2                   0   37.44482            28021.0        6971
# 3                   0   75.21147            29275.0        6328
# 4                   0   44.00151            32770.0        5264
#
#    population_density  poverty_family_below_poverty_level  \
# 0            44.52005                                  85
# 1           482.64430                                 189
# 2           186.16730                                 134
# 3            84.13610                                  87
# 4           119.63230                                  73
#
#    poverty_family_count  race_asian  race_black_africa  race_indian_alaska  \
# 0                  1911          28                 19                  16
# 1                  1359         188                205                  23
# 2                  1961           0                  0                   2
# 3                  1499         171                 69                  26
# 4                  1473          34                 91                   0
#
#    race_islander  race_other  race_two_more  race_white state  total_area  \
# 0              0           6             88        6420    mn   154.37190
# 1              0          67            132        7405    mn    16.69968
# 2              0          18             12        6939    mn    39.33050
# 3              0         305             64        5693    mn    81.04071
# 4              0           0            122        5017    mn    44.60017
#
#    unemployed  water_area  education_less_than_high_school_rate  \
# 0         136    6.640769                              0.073879
# 1         233    0.082887                              0.062836
# 2         151    1.885683                              0.064509
# 3         186    5.829235                              0.066840
# 4         154    0.598656                              0.048686
#
#    education_high_school_graduate_rate  education_college_rate  \
# 0                             0.386324                0.371592
# 1                             0.217096                0.405887
# 2                             0.343973                0.325670
# 3                             0.316840                0.322917
# 4                             0.293309                0.392473
#
#    education_bachelor_rate  education_master_rate  \
# 0                 0.125110               0.034521
# 1                 0.190773               0.080668
# 2                 0.190625               0.061607
# 3                 0.185185               0.078125
# 4                 0.195341               0.050777
#
#    education_professional_school_rate  education_doctoral_rate  \
# 0                            0.005717                 0.002858
# 1                            0.012171                 0.030569
# 2                            0.006696                 0.006920
# 3                            0.010417                 0.019676
# 4                            0.014934                 0.004480
#
#    race_white_rate  race_black_africa_rate  race_indian_alaska_rate  \
# 0         0.976129                0.002889                 0.002433
# 1         0.923317                0.025561                 0.002868
# 2         0.995410                0.000000                 0.000287
# 3         0.899652                0.010904                 0.004109
# 4         0.953078                0.017287                 0.000000
#
#    race_asian_rate  race_islander_rate  race_other_rate  race_two_more_rate  \
# 0         0.004257                 0.0         0.000912            0.013380
# 1         0.023441                 0.0         0.008354            0.016459
# 2         0.000000                 0.0         0.002582            0.001721
# 3         0.027023                 0.0         0.048198            0.010114
# 4         0.006459                 0.0         0.000000            0.023176
#
#    employ_rate  poverty_family_below_poverty_level_rate  \
# 0     0.963293                                 0.044479
# 1     0.953660                                 0.139073
# 2     0.959200                                 0.068332
# 3     0.949305                                 0.058039
# 4     0.949359                                 0.049559
#
#    heating_fuel_gas_rate  heating_fuel_electricity_rate  \
# 0               0.680649                       0.177285
# 1               0.806726                       0.169955
# 2               0.777613                       0.163084
# 3               0.607201                       0.241135
# 4               0.627021                       0.259259
#
#    heating_fuel_fuel_oil_kerosene_rate  heating_fuel_coal_coke_rate  \
# 0                             0.038781                     0.079145
# 1                             0.007623                     0.008969
# 2                             0.016679                     0.025574
# 3                             0.033279                     0.102564
# 4                             0.024517                     0.050078
#
#    heating_fuel_solar_rate  heating_fuel_other_rate  heating_fuel_none_rate  \
# 0                      0.0                 0.020182                0.003957
# 1                      0.0                 0.006726                0.000000
# 2                      0.0                 0.006301                0.010749
# 3                      0.0                 0.008729                0.007092
# 4                      0.0                 0.022953                0.016171
#
#    solar_panel_area_divided_by_area  solar_panel_area_per_capita  \
# 0                          0.000000                     0.000000
# 1                         17.801218                     0.037067
# 2                          1.640095                     0.009253
# 3                          0.000000                     0.000000
# 4                          1.368842                     0.011598
#
#    tile_count_residential  tile_count_nonresidential  \
# 0                     0.0                        0.0
# 1                    17.0                        8.0
# 2                     3.0                        0.0
# 3                     0.0                        0.0
# 4                     4.0                        1.0
#
#    solar_system_count_residential  solar_system_count_nonresidential  \
# 0                             0.0                                0.0
# 1                            15.0                                6.0
# 2                             3.0                                0.0
# 3                             0.0                                0.0
# 4                             4.0                                1.0
#
#    total_panel_area_residential  total_panel_area_nonresidential  \
# 0                      0.000000                         0.000000
# 1                    297.274652                       836.161809
# 2                     64.505776                         0.000000
# 3                      0.000000                         0.000000
# 4                     61.050581                       103.532723
#
#    median_household_income  electricity_price_residential  \
# 0                  64232.0                          12.12
# 1                  49778.0                          12.12
# 2                  63355.0                          12.12
# 3                  71599.0                          12.12
# 4                  68401.0                          12.12
#
#    electricity_price_commercial  electricity_price_industrial  \
# 0                          9.44                          7.02
# 1                          9.44                          7.02
# 2                          9.44                          7.02
# 3                          9.44                          7.02
# 4                          9.44                          7.02
#
#   electricity_price_transportation  electricity_price_overall  \
# 0                              9.5                       9.53
# 1                              9.5                       9.53
# 2                              9.5                       9.53
# 3                              9.5                       9.53
# 4                              9.5                       9.53
#
#    electricity_consume_residential  electricity_consume_commercial  \
# 0                              762                            6743
# 1                              762                            6743
# 2                              762                            6743
# 3                              762                            6743
# 4                              762                            6743
#
#    electricity_consume_industrial  electricity_consume_total  household_count  \
# 0                          182201                     189706             2527
# 1                          182201                     189706             2230
# 2                          182201                     189706             2698
# 3                          182201                     189706             1833
# 4                          182201                     189706             1917
#
#    average_household_size  housing_unit_count  housing_unit_occupied_count  \
# 0                    2.58                2931                         2527
# 1                    2.75                2356                         2230
# 2                    2.55                2909                         2698
# 3                    2.57                2226                         1833
# 4                    2.74                2004                         1917
#
#    housing_unit_median_value  housing_unit_median_gross_rent     lat     lon  \
# 0                   192500.0                           814.0  45.369 -94.282
# 1                   157000.0                           733.0     NaN     NaN
# 2                   182400.0                           692.0  45.460 -94.425
# 3                   251400.0                           681.0  45.507 -94.388
# 4                   208600.0                           882.0  45.457 -94.182
#
#    elevation  heating_design_temperature  cooling_design_temperature  \
# 0      358.0                       -16.7                       25.78
# 1        NaN                         NaN                         NaN
# 2      358.0                       -16.7                       25.78
# 3      358.0                       -16.7                       25.78
# 4      358.0                       -16.7                       25.78
#
#    earth_temperature_amplitude  frost_days  air_temperature  \
# 0                        24.07       154.0              5.4
# 1                          NaN         NaN              NaN
# 2                        24.07       154.0              5.4
# 3                        24.07       154.0              5.4
# 4                        24.07       154.0              5.4
#
#    relative_humidity  daily_solar_radiation  atmospheric_pressure  wind_speed  \
# 0              0.695                   3.76                  97.4         4.4
# 1                NaN                    NaN                   NaN         NaN
# 2              0.695                   3.76                  97.4         4.4
# 3              0.695                   3.76                  97.4         4.4
# 4              0.695                   3.76                  97.4         4.4
#
#    earth_temperature  heating_degree_days  cooling_degree_days  \
# 0                5.7               4810.0               1278.0
# 1                NaN                  NaN                  NaN
# 2                5.7               4810.0               1278.0
# 3                5.7               4810.0               1278.0
# 4                5.7               4810.0               1278.0
#
#    age_18_24_rate  age_25_34_rate  age_more_than_85_rate  age_75_84_rate  \
# 0        0.078759        0.095028               0.008058        0.046374
# 1        0.377182        0.108603               0.009975        0.039526
# 2        0.079902        0.093817               0.032277        0.050782
# 3        0.283660        0.075221               0.005689        0.041245
# 4        0.090616        0.142477               0.005509        0.028875
#
#    age_35_44_rate  age_45_54_rate  age_65_74_rate  age_55_64_rate  \
# 0        0.109624        0.189600        0.085145        0.157671
# 1        0.095885        0.091521        0.034040        0.060973
# 2        0.120069        0.151485        0.079759        0.114474
# 3        0.075695        0.133534        0.076327        0.138432
# 4        0.120631        0.149506        0.060410        0.128609
#
#    age_10_14_rate  age_15_17_rate  age_5_9_rate  household_type_family_rate  \
# 0        0.075262        0.045157      0.064771                    0.756233
# 1        0.036284        0.024314      0.061721                    0.609417
# 2        0.100273        0.057381      0.065701                    0.726835
# 3        0.041403        0.035556      0.048357                    0.817785
# 4        0.049962        0.039704      0.103723                    0.768388
#
#    dropout_16_19_inschool_rate  occupation_construction_rate  \
# 0                     1.000000                      0.113757
# 1                     0.966867                      0.066945
# 2                     0.989605                      0.050986
# 3                     0.988485                      0.095607
# 4                     0.946565                      0.068237
#
#    occupation_public_rate  occupation_information_rate  \
# 0                0.024096                     0.012609
# 1                0.018561                     0.011053
# 2                0.024789                     0.004789
# 3                0.022394                     0.014355
# 4                0.014548                     0.011084
#
#    occupation_finance_rate  occupation_education_rate  \
# 0                 0.044830                   0.203699
# 1                 0.046507                   0.410636
# 2                 0.081972                   0.256338
# 3                 0.029859                   0.300316
# 4                 0.056460                   0.240734
#
#    occupation_administrative_rate  occupation_manufacturing_rate  \
# 0                        0.053797                       0.177080
# 1                        0.034619                       0.103024
# 2                        0.085352                       0.197183
# 3                        0.063164                       0.144416
# 4                        0.125390                       0.158989
#
#    occupation_wholesale_rate  occupation_retail_rate  \
# 0                   0.021855                0.117960
# 1                   0.010636                0.103233
# 2                   0.020845                0.100845
# 3                   0.035889                0.085558
# 4                   0.027710                0.123311
#
#    occupation_transportation_rate  occupation_arts_rate  \
# 0                        0.063603              0.063323
# 1                        0.032534              0.068613
# 2                        0.046197              0.048169
# 3                        0.039334              0.095607
# 4                        0.058538              0.041912
#
#    occupation_agriculture_rate  occupancy_vacant_rate  occupancy_owner_rate  \
# 0                     0.059681               0.137837              0.776868
# 1                     0.004797               0.053480              0.683786
# 2                     0.030704               0.072534              0.776212
# 3                     0.035889               0.176550              0.745283
# 4                     0.029789               0.043413              0.678643
#
#    mortgage_with_rate  transportation_home_rate  \
# 0            0.627580                  0.088343
# 1            0.644320                  0.135403
# 2            0.640390                  0.033475
# 3            0.637734                  0.135988
# 4            0.601471                  0.042524
#
#    transportation_car_alone_rate  transportation_walk_rate  \
# 0                       0.795371                  0.019193
# 1                       0.596433                  0.091590
# 2                       0.841986                  0.034894
# 3                       0.677795                  0.079020
# 4                       0.843848                  0.016731
#
#    transportation_carpool_rate  transportation_motorcycle_rate  \
# 0                     0.086367                        0.003387
# 1                     0.095332                        0.000000
# 2                     0.076879                        0.008794
# 3                     0.086677                        0.001225
# 4                     0.088184                        0.000000
#
#    transportation_bicycle_rate  transportation_public_rate  \
# 0                     0.002258                    0.003669
# 1                     0.000000                    0.064509
# 2                     0.000000                    0.000000
# 3                     0.001838                    0.014395
# 4                     0.000000                    0.002440
#
#    travel_time_less_than_10_rate  travel_time_10_19_rate  \
# 0                       0.130341                0.212693
# 1                       0.239878                0.431373
# 2                       0.236865                0.206927
# 3                       0.190358                0.344913
# 4                       0.119767                0.344376
#
#    travel_time_20_29_rate  travel_time_30_39_rate  travel_time_40_59_rate  \
# 0                0.213932                0.241176                0.088854
# 1                0.175452                0.050166                0.028520
# 2                0.262107                0.199296                0.042559
# 3                0.251684                0.114498                0.060262
# 4                0.294503                0.098289                0.046960
#
#    travel_time_60_89_rate  health_insurance_public_rate  \
# 0                0.067802                      0.249962
# 1                0.008403                      0.245761
# 2                0.041385                      0.255264
# 3                0.021624                      0.185051
# 4                0.065890                      0.272710
#
#    health_insurance_none_rate  age_median  travel_time_average  \
# 0                    0.070330        43.9                 29.0
# 1                    0.043890        21.9                 22.0
# 2                    0.037171        39.6                 21.0
# 3                    0.050727        30.9                 21.0
# 4                    0.023424        34.5                 25.0
#
#    voting_2016_dem_percentage  voting_2016_gop_percentage  \
# 0                    0.323796                    0.602874
# 1                    0.323796                    0.602874
# 2                    0.323796                    0.602874
# 3                    0.323796                    0.602874
# 4                    0.323796                    0.602874
#
#    voting_2016_dem_win  voting_2012_dem_percentage  \
# 0                False                       0.429
# 1                False                       0.429
# 2                False                       0.429
# 3                False                       0.429
# 4                False                       0.429
#
#    voting_2012_gop_percentage  voting_2012_dem_win  \
# 0                        0.55                False
# 1                        0.55                False
# 2                        0.55                False
# 3                        0.55                False
# 4                        0.55                False
#
#    number_of_years_of_education  diversity  \
# 0                     13.232410   0.046960
# 1                     14.192188   0.145934
# 2                     13.647991   0.009150
# 3                     13.858796   0.187334
# 4                     13.850956   0.090766
#
#    number_of_solar_system_per_household  incentive_count_residential  \
# 0                              0.000000                           34
# 1                              0.006726                           34
# 2                              0.001112                           34
# 3                              0.000000                           34
# 4                              0.002087                           34
#
#    incentive_count_nonresidential  incentive_residential_state_level  \
# 0                              39                                 11
# 1                              39                                 11
# 2                              39                                 11
# 3                              39                                 11
# 4                              39                                 11
#
#    incentive_nonresidential_state_level  net_metering  feedin_tariff  \
# 0                                    13            34              0
# 1                                    13            34              0
# 2                                    13            34              0
# 3                                    13            34              0
# 4                                    13            34              0
#
#    cooperate_tax  property_tax  sales_tax  rebate  avg_electricity_retail_rate
# 0              0            25         12       0                         9.46
# 1              0            25         12       0                         9.46
# 2              0            25         12       0                         9.46
# 3              0            25         12       0                         9.46
# 4              0            25         12       0                         9.46

# %%
len(df['fips'].unique())
# Out:
# 72537

# %%
_ = plt.boxplot(df['tile_count'])
plt.show()
_ = plt.hist(df['tile_count'])
plt.show()
df['tile_count'].describe()
len(df[df['tile_count'] > 0])/len(df)
df_tiles = df[df['tile_count'] >10]
_ = df_tiles['tile_count'].hist()
plt.show()
_ = df['solar_panel_area_divided_by_area'].hist()
plt.show()
df['solar_panel_area_divided_by_area'].describe()
# Out:
# count    72537.000000
# mean        30.255787
# std         86.337406
# min          0.000000
# 25%          1.000000
# 50%          4.000000
# 75%         22.000000
# max       4468.000000
# Name: tile_count, dtype: float64
# 0.77557660228573
# count    72513.000000
# mean       359.605537
# std        918.878666
# min          0.000000
# 25%          0.000000
# 50%         20.780833
# 75%        212.018024
# max      16357.357979
# Name: solar_panel_area_divided_by_area, dtype: float64

# %%
df['solar_panel_area_divided_by_area'].describe()
# Out:
# count    72513.000000
# mean       359.605537
# std        918.878666
# min          0.000000
# 25%          0.000000
# 50%         20.780833
# 75%        212.018024
# max      16357.357979
# Name: solar_panel_area_divided_by_area, dtype: float64

# %%
#Explore columns and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72537 entries, 0 to 72536
# Columns: 168 entries, tile_count to avg_electricity_retail_rate
# dtypes: bool(2), float64(117), int64(46), object(3)
# memory usage: 92.0+ MB

# %%
regression_scatter(df['solar_system_count_residential'], df['solar_system_count_nonresidential'],
                   'Residential System Count', 'Non-residential System Count', 
                  'Relationship between Non-Residential & Residential\n Solar System Count')

# %%
len(df[df['solar_system_count_residential'].isna()])
# Out:
# 0

# %%
df['solar_system_count_residential'].describe()
# Out:
# count    72537.000000
# mean        17.615755
# std         48.970994
# min          0.000000
# 25%          0.000000
# 50%          3.000000
# 75%         12.000000
# max       1404.000000
# Name: solar_system_count_residential, dtype: float64

# %%
#Define variables that may potentially provide additional information about the target variable. Will need
#to remove these look ahead variables so the model is not cheating when it makes its predictions
look_ahead_vars = ['tile_count', 'solar_system_count', 'tile_count_residential', 'tile_count_nonresidential',
                  'solar_system_count_residential', 'solar_system_count_nonresidential', 'total_panel_area',
                   'total_panel_area_residential', 'total_panel_area_nonresidential',
                   'solar_panel_area_divided_by_area', 'solar_panel_area_per_capita',
                   'number_of_solar_system_per_household']

# %%
#Print list of categorical columns
cat_cols = list(df.select_dtypes(exclude=[np.number]).columns.values)
cat_cols
# Out:
# ['county',
#  'state',
#  'electricity_price_transportation',
#  'voting_2016_dem_win',
#  'voting_2012_dem_win']

# %%
df['electricity_price_transportation'] = pd.to_numeric(df['electricity_price_transportation'],errors='coerce')

# %%
_ = sns.histplot(df['electricity_price_transportation'], bins=7)
_ = plt.show()

# %%
df['voting_2016_dem_win'] = np.where(df['voting_2016_dem_win'] == True, 1, 
                                    np.where(df['voting_2016_dem_win'] == False, 0, -1))
df['voting_2016_dem_win'].describe()
# Out:
# count    72537.000000
# mean         0.540097
# std          0.498393
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: voting_2016_dem_win, dtype: float64

# %%
df['voting_2012_dem_win'] = np.where(df['voting_2012_dem_win'] == True, 1, 
                                    np.where(df['voting_2012_dem_win'] == False, 0, -1))
df['voting_2012_dem_win'].describe()
# Out:
# count    72537.000000
# mean         0.490108
# std          0.499906
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: voting_2012_dem_win, dtype: float64

# %%
#Shuffle the data
#df = df.sample(frac=1).reset_index(drop=True)

#define the target variable
target_var = 'solar_system_count_residential'

look_ahead_vars.remove(target_var)
df = df.drop(look_ahead_vars, axis=1)
#df = df.drop(uninformative_vars, axis=1)


#Separate data into x and y
x = df[df.columns.difference([target_var])]
y = df[target_var]

#Split data into train and test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=seed)

train_data = pd.concat([x_train, pd.DataFrame(y_train.values, columns = [target_var], index = y_train.index)], axis=1)
train_data.head()

test_data = pd.concat([x_test, pd.DataFrame(y_test.values, columns = [target_var], index = y_test.index)], axis=1)
# Out:
#        age_10_14_rate  age_15_17_rate  age_18_24_rate  age_25_34_rate  \
# 40203        0.048618        0.033937        0.101430        0.188942
# 47685        0.051011        0.038032        0.102022        0.074253
# 26122        0.014319        0.028873        0.076056        0.175822
# 28802        0.096210        0.048105        0.064869        0.140671
# 30188        0.064026        0.021627        0.099572        0.158887
#
#        age_35_44_rate  age_45_54_rate  age_55_64_rate  age_5_9_rate  \
# 40203        0.110010        0.142612        0.108866      0.060248
# 47685        0.139451        0.154845        0.149110      0.044069
# 26122        0.105634        0.151174        0.175587      0.049765
# 28802        0.130709        0.139942        0.126093      0.097425
# 30188        0.167024        0.130621        0.125482      0.074090
#
#        age_65_74_rate  age_75_84_rate  age_median  age_more_than_85_rate  \
# 40203        0.074357        0.043661        34.1               0.009724
# 47685        0.118624        0.041352        43.9               0.011772
# 26122        0.075587        0.053991        44.2               0.038732
# 28802        0.079203        0.024295        36.7               0.022352
# 30188        0.060385        0.022484        36.0               0.004711
#
#        air_temperature  atmospheric_pressure  average_household_income  \
# 40203              8.6                  96.6              62875.045454
# 47685              NaN                   NaN              64030.472727
# 26122             13.0                 100.9              34294.713870
# 28802             16.0                  98.5              83263.438438
# 30188              8.6                  96.6              84523.967423
#
#        average_household_size  avg_electricity_retail_rate  \
# 40203                    2.33                         7.25
# 47685                    2.41                         7.93
# 26122                    2.05                        10.26
# 28802                    3.08                        14.72
# 30188                    2.70                         7.25
#
#        cooling_degree_days  cooling_design_temperature  cooperate_tax  \
# 40203                659.0                       21.96              0
# 47685                  NaN                         NaN              0
# 26122               2192.0                       30.13              0
# 28802               2409.0                       31.00              0
# 30188                659.0                       21.96              0
#
#                     county  daily_solar_radiation  diversity  \
# 40203        Pierce County                   3.35   0.501541
# 47685         Allen County                    NaN   0.100143
# 26122  Philadelphia County                   3.88   0.111437
# 28802        Sonoma County                   4.94   0.402406
# 30188          King County                   3.35   0.661663
#
#        dropout_16_19_inschool_rate  earth_temperature  \
# 40203                     0.942584                9.0
# 47685                     0.986607                NaN
# 26122                     0.752747               13.0
# 28802                     1.000000               17.1
# 30188                     0.883333                9.0
#
#        earth_temperature_amplitude  education_bachelor  \
# 40203                        14.81                 678
# 47685                          NaN                 195
# 26122                        19.43                 272
# 28802                        18.12                 435
# 30188                        14.81                 826
#
#        education_bachelor_rate  education_college  education_college_rate  \
# 40203                 0.190610               1162                0.326680
# 47685                 0.085377                756                0.330998
# 26122                 0.082225               1190                0.359734
# 28802                 0.159341                956                0.350183
# 30188                 0.264151               1090                0.348577
#
#        education_doctoral  education_doctoral_rate  \
# 40203                  33                 0.009277
# 47685                  51                 0.022329
# 26122                  20                 0.006046
# 28802                   0                 0.000000
# 30188                  20                 0.006396
#
#        education_high_school_graduate  education_high_school_graduate_rate  \
# 40203                            1149                             0.323025
# 47685                             755                             0.330560
# 26122                            1373                             0.415054
# 28802                             735                             0.269231
# 30188                             612                             0.195715
#
#        education_less_than_high_school  education_less_than_high_school_rate  \
# 40203                              184                              0.051729
# 47685                              311                              0.136165
# 26122                              354                              0.107013
# 28802                              500                              0.183150
# 30188                              156                              0.049888
#
#        education_master  education_master_rate  education_population  \
# 40203               328               0.092213                  3557
# 47685               157               0.068739                  2284
# 26122                99               0.029927                  3308
# 28802                92               0.033700                  2730
# 30188               374               0.119603                  3127
#
#        education_professional_school  education_professional_school_rate  \
# 40203                             23                            0.006466
# 47685                             59                            0.025832
# 26122                              0                            0.000000
# 28802                             12                            0.004396
# 30188                             49                            0.015670
#
#        electricity_consume_commercial  electricity_consume_industrial  \
# 40203                            6680                           76502
# 47685                            5451                          341375
# 26122                            5276                          166464
# 28802                            5852                           29582
# 30188                            6680                           76502
#
#        electricity_consume_residential  electricity_consume_total  \
# 40203                              964                      84146
# 47685                             1120                     347946
# 26122                              855                     172595
# 28802                              557                      35991
# 30188                              964                      84146
#
#        electricity_price_commercial  electricity_price_industrial  \
# 40203                          8.22                          4.35
# 47685                          9.44                          5.48
# 26122                          9.60                          7.20
# 28802                         15.73                         12.17
# 30188                          8.22                          4.35
#
#        electricity_price_overall  electricity_price_residential  \
# 40203                       7.40                           9.09
# 47685                       8.14                          10.24
# 26122                      10.31                          13.64
# 28802                      15.42                          16.99
# 30188                       7.40                           9.09
#
#        electricity_price_transportation  elevation  employ_rate  employed  \
# 40203                              8.18      433.0     0.925342      2640
# 47685                               NaN        NaN     0.914199      1513
# 26122                              7.82       76.0     0.816874      1704
# 28802                              8.99      270.0     0.925836      1910
# 30188                              8.18      433.0     0.920277      2528
#
#        feedin_tariff         fips  frost_days  gini_index  \
# 40203             11  53053072312        70.0      0.4223
# 47685              0  21003920100         NaN      0.4457
# 26122              0  42101011900        77.0      0.5199
# 28802              9   6097150601         3.0      0.3199
# 30188             11  53033010800        70.0      0.4053
#
#        health_insurance_none_rate  health_insurance_public_rate  \
# 40203                    0.096142                      0.384965
# 47685                    0.124359                      0.320857
# 26122                    0.190723                      0.424770
# 28802                    0.134785                      0.300391
# 30188                    0.110272                      0.287009
#
#        heating_degree_days  heating_design_temperature  \
# 40203               3430.0                       -2.52
# 47685                  NaN                         NaN
# 26122               2527.0                       -4.78
# 28802               1368.0                        2.57
# 30188               3430.0                       -2.52
#
#        heating_fuel_coal_coke  heating_fuel_coal_coke_rate  \
# 40203                      19                     0.008636
# 47685                      53                     0.038545
# 26122                       0                     0.000000
# 28802                      43                     0.032282
# 30188                      19                     0.011053
#
#        heating_fuel_electricity  heating_fuel_electricity_rate  \
# 40203                      1579                       0.717727
# 47685                      1063                       0.773091
# 26122                       313                       0.151794
# 28802                       251                       0.188438
# 30188                       890                       0.517743
#
#        heating_fuel_fuel_oil_kerosene  heating_fuel_fuel_oil_kerosene_rate  \
# 40203                               0                             0.000000
# 47685                               0                             0.000000
# 26122                             246                             0.119302
# 28802                               0                             0.000000
# 30188                             190                             0.110529
#
#        heating_fuel_gas  heating_fuel_gas_rate  \
# 40203               602               0.273636
# 47685               251               0.182545
# 26122              1464               0.709990
# 28802               990               0.743243
# 30188               620               0.360675
#
#        heating_fuel_housing_unit_count  heating_fuel_none  \
# 40203                             2200                  0
# 47685                             1375                  8
# 26122                             2062                 18
# 28802                             1332                 27
# 30188                             1719                  0
#
#        heating_fuel_none_rate  heating_fuel_other  heating_fuel_other_rate  \
# 40203                0.000000                   0                 0.000000
# 47685                0.005818                   0                 0.000000
# 26122                0.008729                  21                 0.010184
# 28802                0.020270                  10                 0.007508
# 30188                0.000000                   0                 0.000000
#
#        heating_fuel_solar  heating_fuel_solar_rate  household_count  \
# 40203                   0                 0.000000             2200
# 47685                   0                 0.000000             1375
# 26122                   0                 0.000000             2062
# 28802                  11                 0.008258             1332
# 30188                   0                 0.000000             1719
#
#        household_type_family_rate  housing_unit_count  \
# 40203                    0.614091                2384
# 47685                    0.735273                1847
# 26122                    0.391853                2486
# 28802                    0.799550                1356
# 30188                    0.616056                1774
#
#        housing_unit_median_gross_rent  housing_unit_median_value  \
# 40203                           835.0                   254300.0
# 47685                           657.0                   112800.0
# 26122                           826.0                   106400.0
# 28802                          1627.0                   366200.0
# 30188                          1435.0                   307700.0
#
#        housing_unit_occupied_count  incentive_count_nonresidential  \
# 40203                         2200                              30
# 47685                         1375                              25
# 26122                         2062                              31
# 28802                         1332                              85
# 30188                         1719                              30
#
#        incentive_count_residential  incentive_nonresidential_state_level  \
# 40203                           23                                    11
# 47685                           13                                     9
# 26122                           17                                     9
# 28802                           75                                    16
# 30188                           23                                    11
#
#        incentive_residential_state_level  land_area     lat      lon  \
# 40203                                  8   0.953812  47.206 -122.520
# 47685                                  4  80.524760     NaN      NaN
# 26122                                  6   0.266840  39.985  -75.229
# 28802                                 15   0.480929  38.239 -122.612
# 30188                                  8   1.580584  47.548 -122.351
#
#        median_household_income  mortgage_with_rate  net_metering  \
# 40203                  49205.0            0.709544            19
# 47685                  48962.0            0.573094            13
# 26122                  24925.0            0.407080            12
# 28802                  84000.0            0.696352            21
# 30188                  74107.0            0.766635            19
#
#        number_of_years_of_education  occupancy_owner_rate  \
# 40203                     13.903852              0.404362
# 47685                     13.304729              0.603682
# 26122                     12.854293              0.409091
# 28802                     12.846886              0.687316
# 30188                     14.470419              0.601466
#
#        occupancy_vacant_rate  occupation_administrative_rate  \
# 40203               0.077181                        0.068561
# 47685               0.255550                        0.083939
# 26122               0.170555                        0.055164
# 28802               0.017699                        0.069110
# 30188               0.031003                        0.124604
#
#        occupation_agriculture_rate  occupation_arts_rate  \
# 40203                     0.000000              0.131061
# 47685                     0.025116              0.056180
# 26122                     0.000000              0.092136
# 28802                     0.017801              0.101047
# 30188                     0.001187              0.121440
#
#        occupation_construction_rate  occupation_education_rate  \
# 40203                      0.007576                   0.256439
# 47685                      0.070720                   0.218110
# 26122                      0.009977                   0.294014
# 28802                      0.124607                   0.187435
# 30188                      0.049446                   0.241693
#
#        occupation_finance_rate  occupation_information_rate  \
# 40203                 0.078788                     0.000000
# 47685                 0.027098                     0.005948
# 26122                 0.040493                     0.036972
# 28802                 0.065969                     0.013089
# 30188                 0.066851                     0.033623
#
#        occupation_manufacturing_rate  occupation_public_rate  \
# 40203                       0.054167                0.052273
# 47685                       0.187707                0.042300
# 26122                       0.032864                0.133216
# 28802                       0.059686                0.024607
# 30188                       0.074367                0.036392
#
#        occupation_retail_rate  occupation_transportation_rate  \
# 40203                0.159091                        0.096212
# 47685                0.150694                        0.064111
# 26122                0.070423                        0.086268
# 28802                0.165445                        0.060733
# 30188                0.085839                        0.076345
#
#        occupation_wholesale_rate  per_capita_income  population  \
# 40203                   0.027273            26872.0        5245
# 47685                   0.039656            26799.0        3313
# 26122                   0.011150            18772.0        4260
# 28802                   0.054974            27702.0        4116
# 30188                   0.026108            31948.0        4670
#
#        population_density  poverty_family_below_poverty_level  \
# 40203          5498.98600                                 225
# 47685            41.14262                                  95
# 26122         15964.66000                                 195
# 28802          8558.43200                                  36
# 30188          2954.60400                                 133
#
#        poverty_family_below_poverty_level_rate  poverty_family_count  \
# 40203                                 0.166543                  1351
# 47685                                 0.093966                  1011
# 26122                                 0.241337                   808
# 28802                                 0.033803                  1065
# 30188                                 0.125590                  1059
#
#        property_tax  race_asian  race_asian_rate  race_black_africa  \
# 40203             0         977         0.186273                234
# 47685             0          58         0.017507                 80
# 26122             0         127         0.029812               4013
# 28802            38         132         0.032070                  0
# 30188             0        1073         0.229764                463
#
#        race_black_africa_rate  race_indian_alaska  race_indian_alaska_rate  \
# 40203                0.044614                   0                 0.000000
# 47685                0.024147                   0                 0.000000
# 26122                0.942019                   0                 0.000000
# 28802                0.000000                  18                 0.004373
# 30188                0.099143                  46                 0.009850
#
#        race_islander  race_islander_rate  race_other  race_other_rate  \
# 40203              0            0.000000          54         0.010296
# 47685              0            0.000000           0         0.000000
# 26122              0            0.000000          29         0.006808
# 28802             15            0.003644         690         0.167638
# 30188            103            0.022056          36         0.007709
#
#        race_two_more  race_two_more_rate  race_white  race_white_rate  rebate  \
# 40203            444            0.084652        3536         0.674166       0
# 47685             34            0.010263        3141         0.948083       0
# 26122             43            0.010094          48         0.011268       0
# 28802            162            0.039359        3099         0.752915      10
# 30188            566            0.121199        2383         0.510278       0
#
#        relative_humidity  sales_tax state  total_area  \
# 40203              0.707          8    wa    0.953812
# 47685                NaN          0    ky   84.922030
# 26122              0.638          0    pa    0.266840
# 28802              0.526          0    ca    0.480929
# 30188              0.707          8    wa    1.708237
#
#        transportation_bicycle_rate  transportation_car_alone_rate  \
# 40203                     0.000000                       0.766176
# 47685                     0.000000                       0.882510
# 26122                     0.000000                       0.440263
# 28802                     0.004182                       0.803450
# 30188                     0.028226                       0.608468
#
#        transportation_carpool_rate  transportation_home_rate  \
# 40203                     0.102574                  0.040809
# 47685                     0.100134                  0.004673
# 26122                     0.043011                  0.019116
# 28802                     0.110298                  0.045478
# 30188                     0.127016                  0.074597
#
#        transportation_motorcycle_rate  transportation_public_rate  \
# 40203                        0.003676                    0.047426
# 47685                        0.000000                    0.000000
# 26122                        0.000000                    0.442055
# 28802                        0.000000                    0.024046
# 30188                        0.003226                    0.125806
#
#        transportation_walk_rate  travel_time_10_19_rate  \
# 40203                  0.037132                0.394787
# 47685                  0.000000                0.282361
# 26122                  0.055556                0.149817
# 28802                  0.012546                0.300657
# 30188                  0.018952                0.239651
#
#        travel_time_20_29_rate  travel_time_30_39_rate  travel_time_40_59_rate  \
# 40203                0.217708                0.095439                0.139517
# 47685                0.181757                0.228706                0.195842
# 26122                0.194275                0.149817                0.214982
# 28802                0.248631                0.097481                0.151150
# 30188                0.236166                0.201307                0.140305
#
#        travel_time_60_89_rate  travel_time_average  \
# 40203                0.008816                 22.0
# 47685                0.025486                 28.0
# 26122                0.073082                 37.0
# 28802                0.085980                 25.0
# 30188                0.068845                 29.0
#
#        travel_time_less_than_10_rate  unemployed  voting_2012_dem_percentage  \
# 40203                       0.123419         213                       0.543
# 47685                       0.061704         142                       0.255
# 26122                       0.109622         382                       0.852
# 28802                       0.111720         153                       0.708
# 30188                       0.082789         219                       0.688
#
#        voting_2012_dem_win  voting_2012_gop_percentage  \
# 40203                    1                       0.434
# 47685                    0                       0.730
# 26122                    1                       0.141
# 28802                    1                       0.260
# 30188                    1                       0.289
#
#        voting_2016_dem_percentage  voting_2016_dem_win  \
# 40203                    0.496931                    1
# 47685                    0.166852                    0
# 26122                    0.824051                    1
# 28802                    0.707223                    1
# 30188                    0.721489                    1
#
#        voting_2016_gop_percentage  water_area  wind_speed  \
# 40203                    0.421728    0.000000         3.4
# 47685                    0.799753    4.397269         NaN
# 26122                    0.154975    0.000000         4.5
# 28802                    0.228093    0.000000         3.4
# 30188                    0.217145    0.127654         3.4
#
#        solar_system_count_residential
# 40203                             3.0
# 47685                             0.0
# 26122                             1.0
# 28802                            69.0
# 30188                            28.0

# %%
na_cols = find_na_columns(df)
na_cols
# Out:
# ['average_household_income',
#  'gini_index',
#  'land_area',
#  'per_capita_income',
#  'population_density',
#  'total_area',
#  'water_area',
#  'education_less_than_high_school_rate',
#  'education_high_school_graduate_rate',
#  'education_college_rate',
#  'education_bachelor_rate',
#  'education_master_rate',
#  'education_professional_school_rate',
#  'education_doctoral_rate',
#  'race_white_rate',
#  'race_black_africa_rate',
#  'race_indian_alaska_rate',
#  'race_asian_rate',
#  'race_islander_rate',
#  'race_other_rate',
#  'race_two_more_rate',
#  'employ_rate',
#  'poverty_family_below_poverty_level_rate',
#  'heating_fuel_gas_rate',
#  'heating_fuel_electricity_rate',
#  'heating_fuel_fuel_oil_kerosene_rate',
#  'heating_fuel_coal_coke_rate',
#  'heating_fuel_solar_rate',
#  'heating_fuel_other_rate',
#  'heating_fuel_none_rate',
#  'median_household_income',
#  'electricity_price_transportation',
#  'average_household_size',
#  'housing_unit_median_value',
#  'housing_unit_median_gross_rent',
#  'lat',
#  'lon',
#  'elevation',
#  'heating_design_temperature',
#  'cooling_design_temperature',
#  'earth_temperature_amplitude',
#  'frost_days',
#  'air_temperature',
#  'relative_humidity',
#  'daily_solar_radiation',
#  'atmospheric_pressure',
#  'wind_speed',
#  'earth_temperature',
#  'heating_degree_days',
#  'cooling_degree_days',
#  'age_18_24_rate',
#  'age_25_34_rate',
#  'age_more_than_85_rate',
#  'age_75_84_rate',
#  'age_35_44_rate',
#  'age_45_54_rate',
#  'age_65_74_rate',
#  'age_55_64_rate',
#  'age_10_14_rate',
#  'age_15_17_rate',
#  'age_5_9_rate',
#  'household_type_family_rate',
#  'dropout_16_19_inschool_rate',
#  'occupation_construction_rate',
#  'occupation_public_rate',
#  'occupation_information_rate',
#  'occupation_finance_rate',
#  'occupation_education_rate',
#  'occupation_administrative_rate',
#  'occupation_manufacturing_rate',
#  'occupation_wholesale_rate',
#  'occupation_retail_rate',
#  'occupation_transportation_rate',
#  'occupation_arts_rate',
#  'occupation_agriculture_rate',
#  'occupancy_vacant_rate',
#  'occupancy_owner_rate',
#  'mortgage_with_rate',
#  'transportation_home_rate',
#  'transportation_car_alone_rate',
#  'transportation_walk_rate',
#  'transportation_carpool_rate',
#  'transportation_motorcycle_rate',
#  'transportation_bicycle_rate',
#  'transportation_public_rate',
#  'travel_time_less_than_10_rate',
#  'travel_time_10_19_rate',
#  'travel_time_20_29_rate',
#  'travel_time_30_39_rate',
#  'travel_time_40_59_rate',
#  'travel_time_60_89_rate',
#  'health_insurance_public_rate',
#  'health_insurance_none_rate',
#  'age_median',
#  'travel_time_average',
#  'voting_2016_dem_percentage',
#  'voting_2016_gop_percentage',
#  'voting_2012_dem_percentage',
#  'voting_2012_gop_percentage',
#  'number_of_years_of_education',
#  'diversity']

# %%
for col in na_cols:
    train_data, test_data = impute_values(train_data, test_data, col,'county', 'median')

# %%
na_cols = find_na_columns(train_data)
na_cols
# Out:
# ['air_temperature',
#  'atmospheric_pressure',
#  'cooling_degree_days',
#  'cooling_design_temperature',
#  'daily_solar_radiation',
#  'dropout_16_19_inschool_rate',
#  'earth_temperature',
#  'earth_temperature_amplitude',
#  'electricity_price_transportation',
#  'elevation',
#  'frost_days',
#  'heating_degree_days',
#  'heating_design_temperature',
#  'housing_unit_median_gross_rent',
#  'housing_unit_median_value',
#  'land_area',
#  'lat',
#  'lon',
#  'median_household_income',
#  'population_density',
#  'relative_humidity',
#  'total_area',
#  'voting_2012_dem_percentage',
#  'voting_2012_gop_percentage',
#  'voting_2016_dem_percentage',
#  'voting_2016_gop_percentage',
#  'water_area',
#  'wind_speed']

# %%
for col in na_cols:
    print(col, ' has ', len(train_data[train_data[col].isna()]), ' missing')
# Out:
# air_temperature  has  5  missing
# atmospheric_pressure  has  5  missing
# cooling_degree_days  has  5  missing
# cooling_design_temperature  has  5  missing
# daily_solar_radiation  has  5  missing
# dropout_16_19_inschool_rate  has  1  missing
# earth_temperature  has  5  missing
# earth_temperature_amplitude  has  5  missing
# electricity_price_transportation  has  4302  missing
# elevation  has  5  missing
# frost_days  has  5  missing
# heating_degree_days  has  5  missing
# heating_design_temperature  has  5  missing
# housing_unit_median_gross_rent  has  1  missing
# housing_unit_median_value  has  1  missing
# land_area  has  3  missing
# lat  has  5  missing
# lon  has  5  missing
# median_household_income  has  1  missing
# population_density  has  3  missing
# relative_humidity  has  5  missing
# total_area  has  3  missing
# voting_2012_dem_percentage  has  4902  missing
# voting_2012_gop_percentage  has  4902  missing
# voting_2016_dem_percentage  has  3  missing
# voting_2016_gop_percentage  has  3  missing
# water_area  has  3  missing
# wind_speed  has  5  missing

# %%
#Drop the columns that had almost 5,000 rows of missing data.
drop_cols = ['electricity_price_transportation','voting_2012_dem_percentage','voting_2012_gop_percentage']
train_data = train_data.drop(drop_cols, axis=1)
test_data = test_data.drop(drop_cols, axis=1)

# %%
'voting_2012_dem_percentage' in train_data.columns
# Out:
# False

# %%
len(train_data)
# Out:
# 58029

# %%
#Drop any remaining rows with n/a values
train_data = train_data.dropna()
len(train_data)
test_data = test_data.dropna()
len(test_data)
# Out:
# 58018
# 14502

# %%
#Define variables that are uniformative for what the model is trying to predict
uninformative_vars = ['fips', 'county', 'state']
#'lat', 'lon'
train_data = train_data.drop(uninformative_vars, axis=1)
test_data = test_data.drop(uninformative_vars, axis=1)

# %%
# correlation_matrix = train_data.corr()
# corr_df = pd.DataFrame(correlation_matrix.unstack(),columns = ['correlation_coef'])
# corr_df = corr_df.reset_index()
# corr_df_significant = corr_df[((corr_df['correlation_coef'] > .8)|(corr_df['correlation_coef'] < -.8))&(corr_df['level_0'] != corr_df['level_1'])]
# len(corr_df_significant['level_0'].unique())

# %%
train_data, dropped_cols = remove_correlation(train_data, target_var)
# Out:
# /var/folders/8w/yzz7q0p146x4qrt7dwp0mhy40000gn/T/ipykernel_78489/3694462228.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['correlation_coef'] = abs(subset['correlation_coef'])

# %%
test_data = test_data.drop(dropped_cols, axis=1)

# %%
# if train_data['education_college'].min() > 0:
#     pt = PowerTransformer('box-cox')
# else:
#     pt = PowerTransformer('yeo-johnson')
# fig, axes = plt.subplots(1,4, figsize=(15,3))
# _ = train_data.hist('education_college', ax = axes[0])
# #df['log_col'] = df[col].apply(lambda x: np.log(x+1))
# train_data[["log_col"]] = pd.DataFrame(pt.fit_transform(traintransformation_comparison_data[['education_college']]), columns=['education_college'])
# _ = train_data.hist('log_col', ax = axes[1])
# mms = Mintransformation_comparisonMaxScaler()
# title_text = 'Comparing Transformations of '+column
# axes1.set_xlabel('common xlabel')
# _ = plt.title(title_text)
# _ = plt.show()

# %%
# pt = PowerTransformer('box-cox')
# pt2 = PowerTransformer('yeo-johnson')
# fig, axes = plt.subplots(1,2, figsize=(15,3))
# _ = train_data.hist('education_college', ax = axes[0])
# train_data[["Box_Cox"]] = pd.DataFrame(pt.fit_transform(train_data[['education_college']]), columns=['education_college'])
# _ = train_data.hist('Box_Cox', ax = axes[1])
# train_data[["Yeo_Johnson"]] = pd.DataFrame(pt2.fit_transform(train_data[['education_college']]), columns=['education_college'])
# _ = train_data.hist('Box_Cox', ax = axes[2])
# _ = plt.title('Comparing Power Transformation Methods:\n Education College')
# _ = plt.show()
# train_data = train_data.drop(['Box_Cox', 'Yeo_Johnson'], axis=1)

# %%
# transformation_comparison(train_data, 'education_college')

# %%
#Investigate distribution of values for numeric columns - determine type of transformation to fix scewness and 
#scale discrepencies in the data
no_plot = list()
for col in list(train_data.select_dtypes(include=[np.number]).columns.values):
    try:
        transformation_comparison(train_data, col)
    except:
        no_plot.append(col)
        continue

# %%
no_plot
# Out:
# []

# %% [markdown]
# From the distributions above, the log transformation does the best job of making the distributions more Gaussian. Will apply this transformation to all of the data.

# %%
train_data = train_data.drop(['log_col', 'min_max_col', 'standar_scaler_col'], axis=1)

# %%
numeric_cols = list(train_data.select_dtypes(include=[np.number]).columns.values)
pos_cols = [col for col in numeric_cols if train_data[col].min() > 0 and test_data[col].min() > 0 and col not in no_plot]
nonpos_cols = [col for col in numeric_cols if col not in pos_cols and col not in no_plot and col != target_var]

#Use box-cox method to transform positive columns
pt = PowerTransformer('box-cox')
print(pt.fit(train_data[pos_cols]))
train_data[pos_cols] = pt.transform(train_data[pos_cols])
test_data[pos_cols] = pt.transform(test_data[pos_cols])

#Use yeo-johnson method to transform columns with negative values
pt2 = PowerTransformer('yeo-johnson')
print(pt2.fit(train_data[nonpos_cols]))
train_data[nonpos_cols] = pt2.transform(train_data[nonpos_cols])
test_data[nonpos_cols] = pt2.transform(test_data[nonpos_cols])
# Out:
# PowerTransformer(method='box-cox')
# PowerTransformer()

# %%
#Define variables that may potentially provide additional information about the target variable. Will need
#to remove these look ahead variables so the model is not cheating when it makes its predictions
look_ahead_vars = ['tile_count', 'solar_system_count', 'tile_count_residential', 'tile_count_nonresidential',
                  'solar_system_count_residential', 'solar_system_count_nonresidential', 'total_panel_area',
                   'total_panel_area_residential', 'total_panel_area_nonresidential',
                   'solar_panel_area_divided_by_area', 'solar_panel_area_per_capita',
                   'number_of_solar_system_per_household']

# %%
target_var = 'solar_system_count_residential'
train_labels = train_data[target_var]
train_data = train_data[train_data.columns.difference([target_var])]
test_labels = test_data[target_var]
test_data = test_data[test_data.columns.difference([target_var])]

# %% [markdown]
# # Model Creation

# %% [markdown]
# ## XGBoost Model Residential

# %%
#======================================================
# setup model parameters, choose RFR or XGB
# if you comment out a parameter it will use default value
#======================================================

# XGB parameters (extreme gradient boosting)
params_xgb = {'objective': 'reg:squarederror',
              #'base_score': 0.5,     # chosen as median of validation set
              'n_estimators': 1000,  # number of trees to use
              'learning_rate': 0.01, 
              #'max_depth': 30,       # how many levels are in each tree
              #'subsample': 1,
              #'colsample_bytree': 0.8,
              # REGULARIZATION  alpha (L2) and lambda (L1)
              #'reg_alpha': 1,
              #'reg_lambda': 0,
             }

# %%
#======================================================
# define the model, uncomment the one you want to use
#======================================================
#model = RandomForestRegressor(**params_rfr)
model = XGBRegressor(**params_xgb)

# %%
# %%time
model.fit(train_data, train_labels)
# Out:
# CPU times: user 24min 16s, sys: 3.91 s, total: 24min 20s
# Wall time: 3min 5s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
test_predictions = model.predict(test_data)
regression_scatter(test_labels, test_predictions, 'Actual Values', 'Predicted Values',
                   'Residential XGBoost Model:\nPredicted vs. Actual Values')#,
#                   '/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/xgboost_residential_system_count_errors_default')

# %%
# histogram
error = test_predictions - test_labels
_ = plt.hist(error, bins = 50)
_ = plt.xlabel("Prediction Error")
_ = plt.ylabel("Count")
_ = plt.title('Residential XGBoost Model:\nPrediction Error')
#plt.savefig("/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/plots/xgboost_residential_system_count_errors_hist_default.png")

# %%
mse = round(mean_squared_error(test_labels, test_predictions))
print(f'the mse is {mse}')
# Out:
# the mse is 503

# %%
fi_xgboost = plot_feature_importance(model.feature_importances_, train_data.columns)

#plt.savefig("/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/plots/xgboost_residential_system_count_feature_importance_default.png")

# %%
#Save model
# pickle.dump(model, open('/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/models/residential/xgboost_residential_solar_system_count.sav', 'wb'))

# %%
#load saved model
#loaded_model = pickle.load(open('/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/models/residential/xgboost_residential.sav', 'rb'))
# plot_feature_importance(loaded_model.feature_importances_, train_data.columns)

# %%
model = XGBRegressor()
# parameters of original run: XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#              max_depth=30, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=1,
#              reg_lambda=0, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
parameters = {'objective':['reg:squarederror'],
              'booster':['gbtree','gblinear'],
              'learning_rate': [.01, 0.1], 
              'max_depth': [7,10,20],
              'min_child_weight': [1, 10 ,20,25],
              'colsample_bytree': [0.8, 0.9, 1],
              'n_estimators': [300,500,600, 1000],
              "reg_alpha"   : [0.5,0.2,1],
              "reg_lambda"  : [0, 2,3,5],
              "gamma"       : [0, 1 ,3]}
random_search = RandomizedSearchCV(estimator=model, param_distributions=parameters,
                                           n_iter=100, cv=5, verbose=3, random_state=seed,
                                           n_jobs=-1, scoring = 'neg_mean_absolute_error')
random_search.fit(train_data, train_labels)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [21:57:10] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-18.796 total time=  20.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-10.174 total time=37.4min
# /opt/anaconda3/envs/mlenv/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [21:57:10] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-18.966 total time=  20.5s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-10.016 total time=37.7min
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-8.182 total time=22.9min
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-8.348 total time=50.5min
# [21:57:10] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-18.543 total time=  20.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.151 total time=13.7min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.500 total time=17.5min
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-8.519 total time=21.4min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-8.407 total time= 6.8min
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-8.368 total time=51.7min
# [21:57:10] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-18.208 total time=  20.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.701 total time=13.7min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.172 total time=17.5min
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-8.464 total time=21.9min
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=0;, score=-7.903 total time=26.0min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-8.140 total time=67.6min
# [21:57:10] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-18.573 total time=  20.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.629 total time=13.8min
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.626 total time= 2.5min
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.713 total time= 2.8min
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-9.198 total time= 2.6min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.982 total time= 2.6min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.809 total time= 2.5min
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-7.963 total time=20.5min
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-8.216 total time= 7.4min
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=0;, score=-8.276 total time=27.7min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-8.072 total time=66.9min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.904 total time= 8.4min
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-8.546 total time=29.9min
# [00:27:07] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-17.912 total time= 1.3min
# [00:28:26] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-17.684 total time= 1.3min
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=0;, score=-8.014 total time=40.6min
# [00:26:56] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-17.103 total time= 1.3min
# [00:28:15] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-18.007 total time= 1.3min
# [00:29:35] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-17.510 total time= 1.3min
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=0;, score=-8.375 total time=43.4min
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-9.175 total time=10.0min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=0;, score=-8.229 total time=41.7min
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.148 total time=12.5min
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-8.461 total time= 7.2min
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.230 total time=48.6min
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-8.225 total time= 3.7min
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-8.599 total time= 4.1min
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-8.247 total time= 4.2min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-8.389 total time= 7.3min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=0;, score=-8.044 total time=26.5min
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-8.713 total time=22.0min
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-8.402 total time=29.3min
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-8.428 total time=25.8min
# [CV 3/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-8.840 total time= 6.6min
# [00:44:38] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=20, n_estimators=1000, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.073 total time=  55.1s
# [00:45:33] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=20, n_estimators=1000, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.902 total time=  53.0s
# [00:46:27] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=20, n_estimators=1000, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.971 total time=  50.8s
# [00:47:17] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=20, n_estimators=1000, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.635 total time=  51.0s
# [00:48:09] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=20, n_estimators=1000, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.491 total time=  51.2s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-7.933 total time=32.1min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.292 total time=15.2min
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.290 total time=48.9min
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-9.159 total time= 8.8min
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-8.769 total time=29.4min
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-8.824 total time= 9.1min
# [00:35:44] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-17.960 total time=  20.4s
# [00:36:05] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-17.485 total time=  21.2s
# [00:36:26] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.972 total time=  12.6s
# [00:36:39] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.491 total time=  13.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-8.566 total time= 7.4min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-8.444 total time= 6.1min
# [CV 3/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-8.395 total time=33.1min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.217 total time=14.5min
# [01:37:55] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-17.211 total time=  20.5s
# [01:38:15] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-18.106 total time=  20.4s
# [01:38:36] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-18.141 total time=  20.9s
# [01:38:57] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-17.784 total time=  21.1s
# [01:39:18] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-17.649 total time=  21.1s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-8.779 total time= 5.1min
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-9.141 total time= 5.9min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-9.033 total time= 6.0min
# [01:56:40] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-17.669 total time=  31.0s
# [01:57:11] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-17.160 total time=  24.7s
# [01:57:36] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-17.734 total time=  21.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-8.640 total time=19.6min
# [02:17:33] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-17.103 total time= 1.0min
# [02:18:34] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-17.912 total time= 1.2min
# [02:19:45] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-18.007 total time= 1.4min
# [02:21:09] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-17.683 total time= 1.4min
# [02:22:35] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=3;, score=-17.510 total time= 1.5min
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.843 total time= 5.5min
# [02:29:30] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-17.664 total time=  25.4s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-8.608 total time=22.9min
# [02:52:50] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=25, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-17.210 total time=  55.3s
# [02:53:45] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-18.156 total time=  47.4s
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-8.414 total time=32.9min
# [03:27:25] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.074 total time= 1.3min
# [03:28:45] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.635 total time= 1.2min
# [CV 2/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=1, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-8.845 total time=56.8min
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-9.932 total time=35.4min
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-8.181 total time=22.5min
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-7.964 total time=49.0min
# [23:44:06] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.319 total time=  13.6s
# [23:44:20] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-17.189 total time=  14.5s
# [23:44:34] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-18.066 total time=  15.4s
# [23:44:50] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-17.580 total time=  17.3s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.808 total time= 9.7min
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-8.292 total time=30.6min
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-8.995 total time= 9.5min
# [00:34:58] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-17.082 total time=  23.2s
# [00:35:21] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-17.832 total time=  23.7s
# [00:35:45] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-17.647 total time=  20.5s
# [00:36:05] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.074 total time=  13.2s
# [00:36:19] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.903 total time=  12.6s
# [00:36:31] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-17.635 total time=  12.3s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-8.395 total time= 7.0min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-8.473 total time= 6.5min
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=5;, score=-8.322 total time=33.9min
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-8.251 total time= 5.6min
# [CV 5/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-8.373 total time= 6.7min
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.452 total time=51.1min
# [02:27:27] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-16.955 total time=  28.8s
# [02:27:56] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-17.805 total time=  28.7s
# [02:28:25] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=2;, score=-17.340 total time=  29.1s
# [02:28:54] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
# ...
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-18.736 total time=  19.9s
# [08:12:12] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-19.394 total time=  20.8s
# [08:12:32] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=500, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-19.029 total time=  20.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=1, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=25, n_estimators=1000, objective=reg:squarederror, reg_alpha=1, reg_lambda=2;, score=-8.406 total time=55.0min
# [CV 1/5] END booster=gbtree, colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.483 total time=10.0min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=25, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=3;, score=-8.659 total time=10.4min
# [09:28:13] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=7, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-17.192 total time=  55.0s
# [09:29:08] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=7, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-18.088 total time=  57.8s
# [09:30:06] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=7, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-18.122 total time=  57.1s
# [09:31:03] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=7, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-17.765 total time=  57.9s
# [09:32:01] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=3, learning_rate=0.01, max_depth=7, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-17.631 total time=  58.0s
# [09:32:59] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-17.282 total time=  57.0s
# [09:33:56] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-18.216 total time=  56.3s
# [09:34:53] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-18.219 total time=  55.7s
# [09:35:49] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-17.853 total time=  54.4s
# [09:36:43] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=1, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=20, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-17.728 total time=  53.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=25, n_estimators=300, objective=reg:squarederror, reg_alpha=1, reg_lambda=5;, score=-8.258 total time=11.8min
# [09:49:25] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=0;, score=-19.038 total time=  59.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=1, gamma=3, learning_rate=0.1, max_depth=20, min_child_weight=25, n_estimators=1000, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=5;, score=-8.501 total time=59.3min
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-8.998 total time= 5.1min
# [CV 5/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-8.481 total time= 5.6min
# [CV 3/5] END booster=gbtree, colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-8.631 total time=11.8min
# [11:12:15] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END booster=gblinear, colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-18.208 total time=  38.2s
# [11:12:53] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END booster=gblinear, colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-18.543 total time=  39.3s
# [11:13:33] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END booster=gblinear, colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-18.966 total time=  40.8s
# [11:14:14] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END booster=gblinear, colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-18.796 total time=  42.8s
# [11:14:57] WARNING: ../src/learner.cc:576:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END booster=gblinear, colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=500, objective=reg:squarederror, reg_alpha=1, reg_lambda=0;, score=-18.573 total time=  42.3s
# [CV 1/5] END booster=gbtree, colsample_bytree=1, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=20, n_estimators=500, objective=reg:squarederror, reg_alpha=0.5, reg_lambda=0;, score=-8.439 total time= 9.1min
# [CV 1/5] END booster=gbtree, colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=300, objective=reg:squarederror, reg_alpha=0.2, reg_lambda=2;, score=-7.863 total time=21.5min
# [CV 4/5] END booster=gbtree, colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=1, n_estimators=600, objective=reg:squarederror, reg_alpha=1, reg_lambda=3;, score=-8.551 total time=17.2min
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           enable_categorical=False, gamma=None,
#                                           gpu_id=None, importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None,
#                                           max_delta_step=None, max_depth=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=...
#                    param_distributions={'booster': ['gbtree', 'gblinear'],
#                                         'colsample_bytree': [0.8, 0.9, 1],
#                                         'gamma': [0, 1, 3],
#                                         'learning_rate': [0.01, 0.1],
#                                         'max_depth': [7, 10, 20],
#                                         'min_child_weight': [1, 10, 20, 25],
#                                         'n_estimators': [300, 500, 600, 1000],
#                                         'objective': ['reg:squarederror'],
#                                         'reg_alpha': [0.5, 0.2, 1],
#                                         'reg_lambda': [0, 2, 3, 5]},
#                    random_state=111, scoring='neg_mean_absolute_error',
#                    verbose=3)

# %%
random_search.best_params_
# Out:
# {'reg_lambda': 2,
#  'reg_alpha': 0.2,
#  'objective': 'reg:squarederror',
#  'n_estimators': 300,
#  'min_child_weight': 10,
#  'max_depth': 20,
#  'learning_rate': 0.01,
#  'gamma': 0,
#  'colsample_bytree': 0.8,
#  'booster': 'gbtree'}

# %%
params_xgb = {'reg_lambda': 2,
 'reg_alpha': 0.2,
 'objective': 'reg:squarederror',
 'n_estimators': 300,
 'min_child_weight': 10,
 'max_depth': 20,
 'learning_rate': 0.01,
 'gamma': 0,
 'colsample_bytree': 0.8,
 'booster': 'gbtree'}
#======================================================
# define the model, uncomment the one you want to use
#======================================================
#model = RandomForestRegressor(**params_rfr)
model = XGBRegressor(**params_xgb)

# %%
# %%time
model.fit(train_data, train_labels)
# Out:
# CPU times: user 22min 20s, sys: 10.4 s, total: 22min 31s
# Wall time: 3min 3s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#              max_depth=20, min_child_weight=10, missing=nan,
#              monotone_constraints='()', n_estimators=300, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0.2, reg_lambda=2, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
test_predictions = model.predict(test_data)
regression_scatter(test_labels, test_predictions, 'Actual Values', 'Predicted Values',
                   'Tuned Residential XGBoost Model:\nPredicted vs. Actual Values')#,
#                   "/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/plots/xgboost_residential_system_count_errors_tuned")

# %%
mse = round(mean_squared_error(test_labels, test_predictions))
print(f'the mse is {mse}')
# Out:
# the mse is 514

# %%
fi_xgboost = plot_feature_importance(model.feature_importances_, train_data.columns)

# plt.savefig("/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/plots/xgboost_residential_tuned_system_count_feature_importance.png")

# %%
# histogram
error = test_predictions - test_labels
_ = plt.hist(error, bins = 50)
_ = plt.xlabel("Prediction Error")
_ = plt.ylabel("Count")
_ = plt.title('Tuned Residential XGBoost Model:\nPrediction Error')
#plt.savefig("/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/plots/xgboost_residential_tuned_system_count_errors_hist.png")

# %%
import shap
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(train_data, approximate=True)
shap.summary_plot(shap_values, features=train_data, feature_names=train_data.columns)

plt.savefig("/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/plots/xgboost_residential_tuned_system_count_shap.png")

# %% [markdown]
# ## Random Forest Model

# %%
#======================================================
# define the model, uncomment the one you want to use
#======================================================

#======================================================
# setup model parameters, choose RFR or XGB
# if you comment out a parameter it will use default value
#======================================================
# RFR parameters (random forest regression)
params_rfr = {'n_estimators':1000,
              'criterion':'squared_error', #equivalent to MSE
              #'ccp_alpha':0.001,
              #'max_depth': 10,
              #'min_samples_leaf':1,
              #'min_samples_split':5,
              #'bootstrap':True,
              #'max_features':None
             }

model = RandomForestRegressor(**params_rfr)

# %%
# %%time
model.fit(train_data, train_labels)
# Out:
# CPU times: user 1h 29min 57s, sys: 60 s, total: 1h 30min 57s
# Wall time: 1h 32min 27s
# RandomForestRegressor(n_estimators=1000)

# %%
test_predictions = model.predict(test_data)

regression_scatter(test_labels, test_predictions, 'Actual Values', 'Predicted Values',
                   'Residential Random Forest Model:\nPredicted vs. Actual Values',
                  '/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/rf_residential_system_count_errors_default')

# %%
# histogram
error = test_predictions - test_labels
_ = plt.hist(error, bins = 50)
_ = plt.xlabel("Prediction Error")
_ = plt.ylabel("Count")
_ = plt.title('Residential Random Forest Model:\nPrediction Error')

# %%
mse = mean_squared_error(test_labels, test_predictions)
print(f'the mse is {mse}')
# Out:
# the mse is 552.287959087781

# %%
fi_rf = plot_feature_importance(model.feature_importances_, train_data.columns)

# %%
model = RandomForestRegressor()

parameters = {'criterion':['squared_error'],
              'n_estimators': [300,500,600, 1000],
              'max_features': ['auto', 'sqrt'],
              'max_depth': [7,10,20],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 5],
              'bootstrap': [True, False]}
random_search = RandomizedSearchCV(estimator=model, param_distributions=parameters,
                                           n_iter=50, cv=5, verbose=3, random_state=seed,
                                           n_jobs=-1, scoring = 'neg_mean_absolute_error')
random_search.fit(train_data, train_labels)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 5/5] END bootstrap=False, criterion=e, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   0.6s
# [CV 1/5] END bootstrap=False, criterion=d, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=nan total time=   0.3s
# [CV 4/5] END bootstrap=True, criterion=a, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=nan total time=   0.3s
# [CV 2/5] END bootstrap=False, criterion=s, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.5s
# [CV 4/5] END bootstrap=False, criterion=r, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=False, criterion=u, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=e, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 3/5] END bootstrap=True, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=o, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=600;, score=nan total time=   0.3s
# [CV 4/5] END bootstrap=True, criterion=o, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=nan total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=r, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=d, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=nan total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=_, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600;, score=nan total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=_, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.8s
# [CV 1/5] END bootstrap=True, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.8s
# [CV 5/5] END bootstrap=True, criterion=q, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=nan total time=   0.6s
# [CV 1/5] END bootstrap=False, criterion=e, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=_, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 3/5] END bootstrap=False, criterion=o, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600;, score=nan total time=   0.4s
# [CV 5/5] END bootstrap=False, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 3/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 4/5] END bootstrap=True, criterion=_, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=s, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.7s
# [CV 3/5] END bootstrap=False, criterion=s, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=u, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600;, score=nan total time=   0.5s
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600;, score=-10.984 total time=49.9min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=600;, score=-12.074 total time=34.2min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-9.370 total time=27.2min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=-11.569 total time=39.8min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=1000;, score=-9.651 total time= 8.4min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-9.991 total time= 4.1min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-12.097 total time=84.0min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=600;, score=-10.679 total time=21.6min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=-12.114 total time= 3.7min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=-8.929 total time= 4.0min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=-9.254 total time= 4.1min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500;, score=-11.019 total time=17.9min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500;, score=-10.714 total time=18.1min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=-11.692 total time= 2.9min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=-11.479 total time= 2.9min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-10.397 total time= 2.6min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-10.002 total time= 2.7min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=-12.068 total time= 5.8min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=-8.658 total time=54.1min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=-9.017 total time=91.9min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600;, score=-12.217 total time=34.3min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=-8.740 total time=52.9min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=-9.752 total time= 7.8min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=-10.279 total time= 7.8min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=-10.092 total time= 7.9min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-9.576 total time= 4.2min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-9.087 total time= 4.2min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500;, score=-10.541 total time= 2.6min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=-9.608 total time= 7.9min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=-9.945 total time= 7.9min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=-9.479 total time= 8.6min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=-8.994 total time= 8.6min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=-9.405 total time= 4.6min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-10.506 total time= 4.8min
# [CV 2/5] END bootstrap=True, criterion=r, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.6s
# [CV 5/5] END bootstrap=False, criterion=r, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 3/5] END bootstrap=True, criterion=a, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=nan total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=s, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=s, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=r, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 2/5] END bootstrap=False, criterion=u, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=d, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=nan total time=   0.3s
# [CV 2/5] END bootstrap=False, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=o, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=r, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=nan total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=d, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=nan total time=   0.4s
# [CV 5/5] END bootstrap=False, criterion=s, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.3s
# [CV 3/5] END bootstrap=True, criterion=o, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=nan total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=_, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.8s
# [CV 1/5] END bootstrap=True, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.8s
# [CV 4/5] END bootstrap=False, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=nan total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=u, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.9s
# [CV 4/5] END bootstrap=False, criterion=e, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=e, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=q, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=nan total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=o, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600;, score=nan total time=   0.4s
# [CV 2/5] END bootstrap=False, criterion=q, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.6s
# [CV 5/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 2/5] END bootstrap=False, criterion=r, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=s, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 2/5] END bootstrap=True, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=s, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=q, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=nan total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=-10.395 total time=12.1min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=600;, score=-11.600 total time=35.6min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=600;, score=-12.153 total time=33.9min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-9.285 total time=27.0min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=-11.707 total time=39.6min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=-10.654 total time=37.9min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=1000;, score=-11.994 total time= 3.7min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=-9.782 total time= 3.9min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=-10.093 total time= 3.9min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=-9.515 total time= 2.4min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=-9.077 total time= 2.4min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=-9.690 total time= 2.6min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-9.285 total time=25.3min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-9.614 total time=24.8min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1000;, score=-12.356 total time=56.2min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500;, score=-9.023 total time=45.5min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=-9.238 total time=91.6min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=-9.845 total time= 3.2min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=-10.010 total time= 3.2min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=-9.247 total time= 2.6min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=-11.591 total time=24.0min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600;, score=-12.073 total time=34.4min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=-11.978 total time= 2.9min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=-10.984 total time=40.3min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=-11.709 total time=80.0min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-10.102 total time= 4.8min
# [CV 3/5] END bootstrap=True, criterion=r, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=False, criterion=r, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=a, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=nan total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=d, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=nan total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.5s
# [CV 1/5] END bootstrap=False, criterion=o, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=o, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=u, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=e, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 2/5] END bootstrap=False, criterion=o, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=600;, score=nan total time=   0.3s
# [CV 5/5] END bootstrap=True, criterion=o, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=nan total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=r, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=s, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.3s
# [CV 5/5] END bootstrap=True, criterion=_, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600;, score=nan total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=_, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.8s
# [CV 2/5] END bootstrap=True, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=nan total time=   0.6s
# [CV 5/5] END bootstrap=True, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.8s
# [CV 1/5] END bootstrap=True, criterion=u, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.9s
# [CV 5/5] END bootstrap=False, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=nan total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=_, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=q, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=nan total time=   0.4s
# [CV 3/5] END bootstrap=False, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 1/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=_, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.6s
# [CV 3/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 5/5] END bootstrap=True, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 3/5] END bootstrap=True, criterion=r, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   0.3s
# [CV 4/5] END bootstrap=True, criterion=u, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600;, score=nan total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=-10.929 total time=12.0min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=-10.815 total time=11.4min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=600;, score=-12.356 total time=35.6min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-8.791 total time=25.4min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-9.065 total time=27.3min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=-11.460 total time=39.8min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=1000;, score=-9.242 total time= 8.4min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-9.858 total time= 4.1min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-11.847 total time=83.7min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1000;, score=-11.599 total time=56.0min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500;, score=-9.260 total time=44.5min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=-8.750 total time=54.1min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=-11.143 total time=11.4min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-11.233 total time= 3.5min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-12.065 total time= 3.5min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-11.428 total time= 3.5min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-10.003 total time=26.4min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=-10.598 total time= 3.2min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=-9.501 total time= 2.6min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=-10.672 total time=24.0min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600;, score=-12.356 total time=34.5min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=-11.187 total time= 2.9min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=-11.570 total time= 2.9min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=-11.677 total time=40.3min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=-11.506 total time=80.6min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-9.900 total time= 4.4min
# [CV 1/5] END bootstrap=False, criterion=e, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=r, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=d, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=nan total time=   0.3s
# [CV 2/5] END bootstrap=False, criterion=d, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 2/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.5s
# [CV 2/5] END bootstrap=False, criterion=r, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 2/5] END bootstrap=True, criterion=d, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=nan total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=e, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=o, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=r, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=nan total time=   0.3s
# [CV 3/5] END bootstrap=True, criterion=r, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=s, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.3s
# [CV 3/5] END bootstrap=True, criterion=_, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600;, score=nan total time=   0.5s
# [CV 1/5] END bootstrap=True, criterion=_, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.8s
# [CV 5/5] END bootstrap=True, criterion=u, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=nan total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.8s
# [CV 4/5] END bootstrap=True, criterion=q, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=False, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=nan total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=_, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 3/5] END bootstrap=True, criterion=q, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=nan total time=   0.4s
# [CV 1/5] END bootstrap=False, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=False, criterion=q, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.6s
# [CV 1/5] END bootstrap=False, criterion=r, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=r, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 3/5] END bootstrap=True, criterion=s, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=nan total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=r, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=u, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600;, score=nan total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=q, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=nan total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600;, score=-11.506 total time=50.2min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=-10.411 total time= 3.2min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500;, score=-10.672 total time=39.4min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-8.886 total time=27.3min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=-11.163 total time=36.7min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-9.663 total time= 4.1min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-11.639 total time=83.5min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=600;, score=-10.928 total time=21.4min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1000;, score=-12.073 total time=56.7min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-9.868 total time= 2.6min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-10.204 total time= 2.6min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=-11.725 total time= 5.8min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=-11.461 total time= 5.8min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=-9.268 total time=54.2min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=-10.335 total time=11.4min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=-10.847 total time=11.4min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-11.759 total time= 3.5min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-11.651 total time= 3.5min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-9.837 total time=26.4min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=-10.402 total time= 3.2min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=-8.876 total time= 2.6min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=-9.035 total time= 2.6min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=-11.329 total time=24.0min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=-11.170 total time= 3.7min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=-11.984 total time= 3.7min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=-11.401 total time= 3.7min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=-9.161 total time=52.5min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=-11.285 total time=40.0min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=-9.886 total time= 7.9min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-9.692 total time= 4.2min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500;, score=-9.807 total time= 2.6min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500;, score=-10.157 total time= 2.6min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=-10.158 total time= 7.8min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=-9.784 total time= 7.9min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=-9.599 total time= 8.6min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-9.118 total time= 2.6min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-9.812 total time= 2.6min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=-9.001 total time= 4.6min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=-9.100 total time= 4.5min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=-9.749 total time= 6.8min
# [CV 2/5] END bootstrap=False, criterion=e, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=r, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.2s
# [CV 2/5] END bootstrap=False, criterion=d, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=nan total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=d, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 5/5] END bootstrap=False, criterion=s, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   0.2s
# [CV 3/5] END bootstrap=True, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=r, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 5/5] END bootstrap=False, criterion=u, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=e, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 5/5] END bootstrap=True, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=o, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=nan total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=r, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=nan total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=d, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=nan total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=_, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=600;, score=nan total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=o, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=nan total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=u, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=nan total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=nan total time=   0.6s
# [CV 1/5] END bootstrap=False, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=nan total time=   0.5s
# [CV 5/5] END bootstrap=False, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 2/5] END bootstrap=False, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=nan total time=   0.6s
# [CV 2/5] END bootstrap=False, criterion=e, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=_, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 1/5] END bootstrap=False, criterion=o, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600;, score=nan total time=   0.4s
# [CV 4/5] END bootstrap=False, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 2/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 3/5] END bootstrap=True, criterion=_, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 2/5] END bootstrap=True, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 1/5] END bootstrap=False, criterion=s, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=r, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=q, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=nan total time=   0.3s
# ...
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=-9.535 total time= 4.0min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=-9.075 total time= 4.0min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500;, score=-11.223 total time=17.9min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500;, score=-8.755 total time=44.2min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=-8.931 total time=54.2min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=-10.946 total time=11.4min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=-10.679 total time=11.4min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-9.282 total time=26.4min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-9.609 total time=26.1min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=300;, score=-11.325 total time=23.9min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=-9.253 total time=52.9min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=-11.049 total time=80.0min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-9.456 total time= 2.6min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=-9.582 total time= 4.5min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-9.754 total time= 4.8min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=-10.110 total time= 6.6min
# [CV 1/5] END bootstrap=True, criterion=r, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.6s
# [CV 3/5] END bootstrap=False, criterion=r, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.3s
# [CV 1/5] END bootstrap=True, criterion=a, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=nan total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=d, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=nan total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.5s
# [CV 3/5] END bootstrap=False, criterion=r, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=d, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=nan total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=e, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=o, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=r, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=nan total time=   0.3s
# [CV 4/5] END bootstrap=True, criterion=r, max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=300;, score=nan total time=   0.3s
# [CV 2/5] END bootstrap=False, criterion=s, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=nan total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=o, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=nan total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=_, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.8s
# [CV 5/5] END bootstrap=True, criterion=r, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=nan total time=   0.6s
# [CV 3/5] END bootstrap=False, criterion=a, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=nan total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=q, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   0.3s
# [CV 4/5] END bootstrap=True, criterion=u, max_depth=7, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.9s
# [CV 5/5] END bootstrap=False, criterion=e, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 3/5] END bootstrap=True, criterion=e, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   0.3s
# [CV 5/5] END bootstrap=True, criterion=e, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   0.2s
# [CV 2/5] END bootstrap=False, criterion=o, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600;, score=nan total time=   0.4s
# [CV 1/5] END bootstrap=False, criterion=q, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=False, criterion=r, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=nan total time=   0.3s
# [CV 5/5] END bootstrap=True, criterion=_, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=nan total time=   0.7s
# [CV 2/5] END bootstrap=True, criterion=s, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=nan total time=   0.6s
# [CV 5/5] END bootstrap=True, criterion=r, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000;, score=nan total time=   0.6s
# [CV 4/5] END bootstrap=False, criterion=s, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=nan total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=u, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=600;, score=nan total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=-11.155 total time=12.0min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=-10.647 total time=11.4min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=600;, score=-12.217 total time=35.5min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=500;, score=-11.326 total time=39.9min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000;, score=-8.859 total time=13.3min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=-10.341 total time=36.9min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=1000;, score=-9.516 total time= 8.3min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-10.423 total time= 4.1min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-11.848 total time=83.9min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=600;, score=-10.843 total time=21.5min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=-11.811 total time= 3.7min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=-11.526 total time= 3.8min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500;, score=-9.684 total time= 4.0min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500;, score=-10.434 total time=18.1min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500;, score=-10.864 total time=17.9min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=-11.096 total time= 2.9min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=-11.907 total time= 2.9min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500;, score=-11.365 total time= 2.9min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-10.591 total time= 2.6min
# [CV 1/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=-11.209 total time= 5.8min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=-11.616 total time= 5.8min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=-9.143 total time=53.9min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=-8.825 total time=91.3min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=-11.754 total time= 3.7min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=-11.587 total time= 3.7min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=-8.628 total time=52.6min
# [CV 4/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=-11.504 total time=39.9min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000;, score=-10.523 total time= 7.9min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-8.998 total time= 4.2min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-9.337 total time= 4.2min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500;, score=-10.366 total time= 2.6min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500;, score=-9.983 total time= 2.6min
# [CV 3/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000;, score=-10.339 total time= 7.8min
# [CV 1/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=-8.908 total time= 8.5min
# [CV 4/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=-9.246 total time= 8.6min
# [CV 2/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-9.678 total time= 2.6min
# [CV 5/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-9.213 total time= 2.6min
# [CV 3/5] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=-9.705 total time= 4.5min
# [CV 2/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-10.257 total time= 4.8min
# [CV 5/5] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=-9.898 total time= 6.1min
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestRegressor(criterion='mse',
#                                                    max_depth=10,
#                                                    max_features=None,
#                                                    n_estimators=1000),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['squared_error'],
#                                         'max_depth': [7, 10, 20],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [300, 500, 600, 1000]},
#                    random_state=111, scoring='neg_mean_absolute_error',
#                    verbose=3)

# %%
random_search.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 5,
#  'min_samples_leaf': 5,
#  'max_features': 'sqrt',
#  'max_depth': 20,
#  'criterion': 'squared_error',
#  'bootstrap': False}

# %%
params_rfr = {'n_estimators': 1000,
 'min_samples_split': 5,
 'min_samples_leaf': 5,
 'max_features': 'sqrt',
 'max_depth': 20,
 'criterion': 'squared_error',
 'bootstrap': False}
model = RandomForestRegressor(**params_rfr)

# %%
# %%time
model.fit(train_data, train_labels)
# Out:
# CPU times: user 9min 51s, sys: 5.02 s, total: 9min 56s
# Wall time: 10min 5s
# RandomForestRegressor(bootstrap=False, max_depth=20, max_features='sqrt',
#                       min_samples_leaf=5, min_samples_split=5,
#                       n_estimators=1000)

# %%
mse = mean_squared_error(test_labels, test_predictions)
print(f'the mse is {mse}')
# Out:
# the mse is 552.287959087781

# %%
fi_rf = plot_feature_importance(model.feature_importances_, train_data.columns)

# %%
test_predictions = model.predict(test_data)

regression_scatter(test_labels, test_predictions, 'Actual Values', 'Predicted Values',
                   'Residential Random Forest Model:\nPredicted vs. Actual Values',
                  '/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/rf_residential_system_count_errors_tuned')

# %%
# histogram
error = test_predictions - test_labels
_ = plt.hist(error, bins = 50)
_ = plt.xlabel("Prediction Error")
_ = plt.ylabel("Count")
_ = plt.title('Tuned Residential Random Forest Model:\nPrediction Error')

# %% [markdown]
# # Neural Network Regression

# %%
# Define basic architecture
model = keras.Sequential([
    keras.layers.Dense(128, activation=tf.nn.relu,
                       input_shape=(train_data.shape[1],),
                       name='hidden_layer_1',),
    keras.layers.Dense(1, name='output_layer',)
])

# Define the optimizer 
optimizer = tf.optimizers.Adam()

model.compile(loss='mse',
            optimizer=optimizer,
            metrics=tf.keras.metrics.MeanSquaredError())

# show a summary of the data
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden_layer_1 (Dense)       (None, 128)               13312
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 13,441
# Trainable params: 13,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Display training progress by printing a single dot for each completed epoch
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')
        
# Function to plot how the model is doing during training
# Visualize the model's training progress using the stats stored in the history object. 
# We want to use this data to determine how long to train before the model stops making progress.
def plot_history(history, title=None):
    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Sq. Error')
    plt.title(title)
    plt.plot(history.epoch, np.array(history.history['loss']),
           label='Train Loss')
    plt.plot(history.epoch, np.array(history.history['val_loss']),
           label = 'Val loss')
    plt.legend()
    #plt.ylim([0, 5])

# %%
# If you train too long, you are prone to over-fitting
# this prevents the model from generalizing to data it has never seen before
# early stopping is one way to go about this
# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

# Store training stats
history = model.fit(train_data, train_labels, epochs=1000,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history, 'Residential Neural Network (1 Layer):\n Model Loss')
# Out:
# ...................................................................

# %%
[loss, mse] = model.evaluate(test_data, test_labels, verbose=0)

print("Testing set Mean Sq. Error: {:7.0f}".format(mse))
# Out:
# Testing set Mean Sq. Error:     681

# %%
test_predictions = model.predict(test_data).flatten()

regression_scatter(test_labels, test_predictions, 'Actual Values', 'Predicted Values',
                   'Residential Neural Network (1 Layer):\nPredicted vs. Actual Values',
                  '/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/nn_residential_system_count_errors_1L')

# %%
# histogram
error = test_predictions - test_labels
_ = plt.hist(error, bins = 50)
_ = plt.xlabel("Prediction Error")
_ = plt.ylabel("Count")
_ = plt.title('Single Layer Neural Network Model:\nPrediction Error')

# %% [markdown]
# # Deep learning

# %%
# Define basic architecture
model = keras.Sequential([
    keras.layers.Dense(128, activation=tf.nn.relu, #activation=tf.keras.activations.linear,
                       input_shape=(train_data.shape[1],),
                       name='hidden_layer_1',),
    keras.layers.Dense(128, activation=tf.nn.relu,
                       name='hidden_layer_2',),
    keras.layers.Dense(128, activation=tf.nn.relu,
                       name='hidden_layer_3',),
    keras.layers.Dense(1, name='output_layer',)
])

# Define your optimizer asdf
#optimizer = tf.train.AdamOptimizer()
optimizer = tf.optimizers.Adam()

model.compile(loss='mse',
            optimizer=optimizer,
            metrics=tf.keras.metrics.MeanSquaredError())

# show a summary of the data
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden_layer_1 (Dense)       (None, 128)               13312
# _________________________________________________________________
# hidden_layer_2 (Dense)       (None, 128)               16512
# _________________________________________________________________
# hidden_layer_3 (Dense)       (None, 128)               16512
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 46,465
# Trainable params: 46,465
# Non-trainable params: 0
# _________________________________________________________________
# 2021-12-21 22:48:17.139255: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# If you train too long, you are prone to over-fitting
# this prevents the model from generalizing to data it has never seen before
# early stopping is one way to go about this
# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

# Store training stats
history = model.fit(train_data, train_labels, epochs=1000,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history,'Residential Neural Network (3 Layers):\n Model Loss' )
# Out:
# 2021-12-21 22:49:10.313713: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# ....................................

# %%
[loss, mse] = model.evaluate(test_data, test_labels, verbose=0)

print("Testing set Mean Sq. Error: {:7.0f}".format(mse))
# Out:
# Testing set Mean Sq. Error:     616

# %%
test_predictions = model.predict(test_data).flatten()

regression_scatter(test_labels, test_predictions, 'Actual Values', 'Predicted Values',
                   '3 Layer (no reg) Residential Neural Network:\nPredicted vs. Actual Values',
                  '/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/nn_residential_system_count_errors_1L')

# %%
#reg_alpha=0.2, reg_lambda=2
# Define basic architecture
model = keras.Sequential([
    keras.layers.Dense(128, activation=tf.nn.relu, #activation=tf.keras.activations.linear,
                       input_shape=(train_data.shape[1],),
                       name='hidden_layer_1',),
    keras.layers.Dense(128, activation=tf.nn.relu,
                       name='hidden_layer_2',kernel_regularizer=tf.keras.regularizers.L2(2.)),
    keras.layers.Dense(128, activation=tf.nn.relu,
                       name='hidden_layer_3'),
    keras.layers.Dense(1, name='output_layer',)
])

# Define your optimizer asdf
#optimizer = tf.train.AdamOptimizer()
optimizer = tf.optimizers.Adam()

model.compile(loss='mse',
            optimizer=optimizer,
            metrics=tf.keras.metrics.MeanSquaredError())

# show a summary of the data
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden_layer_1 (Dense)       (None, 128)               13312
# _________________________________________________________________
# hidden_layer_2 (Dense)       (None, 128)               16512
# _________________________________________________________________
# hidden_layer_3 (Dense)       (None, 128)               16512
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 46,465
# Trainable params: 46,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
# If you train too long, you are prone to over-fitting
# this prevents the model from generalizing to data it has never seen before
# early stopping is one way to go about this
# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

# Store training stats
history = model.fit(train_data, train_labels, epochs=1000,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# ................................................................

# %%
[loss, mse] = model.evaluate(test_data, test_labels, verbose=0)

print("Testing set Mean Sq. Error: {:7.0f}".format(mse))
# Out:
# Testing set Mean Sq. Error:     606

# %%
#regularizers.l1_l2(l1=1e-5, l2=1e-4)

#reg_alpha=0.2, reg_lambda=2
# Define basic architecture
model = keras.Sequential([
    keras.layers.Dense(128, activation=tf.nn.relu, #activation=tf.keras.activations.linear,
                       input_shape=(train_data.shape[1],),
                       name='hidden_layer_1'),
    keras.layers.Dense(128, activation=tf.nn.relu,
                       name='hidden_layer_2'),
    keras.layers.Dropout(.2),
    keras.layers.Dense(128, activation=tf.nn.relu,
                       name='hidden_layer_3'),
    keras.layers.Dense(1, name='output_layer',)
])

# Define your optimizer asdf
#optimizer = tf.train.AdamOptimizer()
optimizer = tf.optimizers.Adam()

model.compile(loss='mse',
            optimizer=optimizer,
            metrics=tf.keras.metrics.MeanSquaredError())

# show a summary of the data
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden_layer_1 (Dense)       (None, 128)               13312
# _________________________________________________________________
# hidden_layer_2 (Dense)       (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# hidden_layer_3 (Dense)       (None, 128)               16512
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 46,465
# Trainable params: 46,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
# If you train too long, you are prone to over-fitting
# this prevents the model from generalizing to data it has never seen before
# early stopping is one way to go about this
# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

# Store training stats
history = model.fit(train_data, train_labels, epochs=1000,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history)

# %%
[loss, mse] = model.evaluate(test_data, test_labels, verbose=0)

print("Testing set Mean Sq. Error: {:7.0f}".format(mse))

# %%
test_predictions = model.predict(test_data).flatten()

regression_scatter(test_labels, test_predictions, 'Actual Values', 'Predicted Values',
                   'Residential Deep Neural Network (w/ dropout):\nPredicted vs. Actual Values',
                  '/Users/gabbynyirjesy/Documents/ML for Env Engineering/Solar-Panel-Area-Prediction/deep_nn_residential_system_count_errors')
